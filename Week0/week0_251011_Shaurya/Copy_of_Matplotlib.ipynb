# %% [markdown]
# **NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP.**
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# **Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Exercise 1
#
# **Follow along with these steps**
# * Create a figure object called fig using plt.figure()
# * Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax.
# * Plot (x,y) on that axes and set the labels and titles to match the plot below:

# %%
fig = plt.figure()
axis = fig.add_axes([10,10,1,1])
axis.plot(x,y)

# %% [markdown]
# ## Exercise 2
# **Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig1 = plt.figure()
ax1 = fig1.add_axes([0,0,1,1])
ax2 = fig1.add_axes([0.2,0.5,0.2,0.2])

# %% [markdown]
# **Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig1 = plt.figure()
ax1 = fig1.add_axes([0,0,1,1])
ax2 = fig1.add_axes([0.2,0.5,0.2,0.2])
ax1.plot(x,y)
ax2.plot(x,y)

# %% [markdown]
# ## Exercise 3
#
# **Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig1 = plt.figure()
ax1 = fig1.add_axes([0,0,1,1])
ax2 = fig1.add_axes([0.2,0.5,0.4,0.4])

# %% [markdown]
# **Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
fig1 = plt.figure()
ax1 = fig1.add_axes([0,0,1,1])
ax2 = fig1.add_axes([0.2,0.5,0.4,0.4])
ax1.plot(x,z)
ax2.set_title("zoom")
ax2.set_xlabel("x")
ax2.set_ylabel("y")
ax1.set_xlabel("x")
ax1.set_ylabel("z")
ax2.plot(x,y)
#ax2.plot(x[20:23],y[20:23]) one way could have been this
ax2.set_xlim(20,22)
ax2.set_ylim(30,50)
# Out:
# (30.0, 50.0)

# %% [markdown]
# ## Exercise 4
#
# **Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig,axes = plt.subplots(nrows=1 , ncols = 2)

# %% [markdown]
# **Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
fig,axes = plt.subplots(nrows=1 , ncols = 2)
axes[0].plot(x,y,color = "Blue",linestyle = "--")
axes[1].plot(x,z,color = "red")

# %% [markdown]
# **See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
fig,axes = plt.subplots(nrows=1 , ncols = 2 , figsize=(20,2))
axes[0].plot(x,y,color = "Blue")
axes[1].plot(x,z,color = "red")

# %% [markdown]
# # #**Plots**
#
# Plot the following plots using matplotlib, you many generate your own data or get it from the internet:
#
# 1. Histogram
# 2. Scatter Plot
# 3. Boxplot
# 4. Pie charts
#
# (Bonus - Read up on the use-case of histograms in EDA and ML in general, they are VERY useful! Also, look up **Violin plots** if you have extra time)

# %%
import numpy as np
data = np.random.randn(10000)
plt.figure(figsize=(3,3))
plt.hist(data , edgecolor = "black")
X = np.random.randint(1,100,size=(100))
Y = np.random.randint(1,100,size=(100))
plt.figure(figsize=(3,3))
plt.scatter(X,Y,color="orange")
plt.figure(figsize=(3,3))
plt.boxplot(data)
plt.figure()
data1 = np.random.randint(10,60,size=(5))
labels = ["L1","L2","L3","L4","L5"]
plt.pie(data1,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7acb906fd5e0>,
#   <matplotlib.patches.Wedge at 0x7acb90405700>,
#   <matplotlib.patches.Wedge at 0x7acb90405c10>,
#   <matplotlib.patches.Wedge at 0x7acb90406150>,
#   <matplotlib.patches.Wedge at 0x7acb90406540>],
#  [Text(0.5795927377056399, 0.9349183164313776, 'L1'),
#   Text(-0.6812065692051499, 0.8636883755566874, 'L2'),
#   Text(-1.0720908261854944, 0.24621385096883552, 'L3'),
#   Text(-0.7288389852343363, -0.8238893940345288, 'L4'),
#   Text(0.7288390048839012, -0.823889376651893, 'L5')])
